# %%
import hangman
# Out:
# Let's play HANGMAN!!! Topic: SPORTS
#
# May the odds be ever in your favour!!
#
# Select difficulty level
# 1. Beginner: Noob
# 2. Intermediate (default): I know English
# 3. Advanced: Dictionary crammer
#
# Enter your choice: 2
#
# Selecting intermediate, you have  14  trials, including  5  wrong attempts
#      _________
#      |
#      |
#      |
#      |
#      |
# --------------
#
# The word is:      _ _ _ _ _ _ _ _ _
#
# Your guesses till now are: "  "
# Enter a character: h
#      _________
#      |    |
#      |
#      |
#      |
#      |
# --------------
#
# The word is:      _ _ _ _ _ _ _ _ _
#
# Remaining trials =  13 , Remaining wrong attempts =  4
# Your guesses till now are: " h "
# Enter a character: b
#      _________
#      |    |
#      |    0
#      |
#      |
#      |
# --------------
#
# The word is:      _ _ _ _ _ _ _ _ _
#
# Remaining trials =  12 , Remaining wrong attempts =  3
# Your guesses till now are: " hb "
# Enter a character: s
#      _________
# ...
